# %%
import os

# Set the directory to the root
os.chdir("..")

# %%
# Tests
import spotipy
import pandas as pd 
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util
import utils.spotify_functions as spotify_functions

# %%
# Get Spotify Authentication
keys_path = "auth/spotify_keys.ini"
spotify_auth = spotify_functions.SpotifyAuth(keys_path)

# Authenticate Spotify and get credentials manager as sp
client_credentials_manager = SpotifyClientCredentials(spotify_auth.client_id, spotify_auth.client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# don't need this because only searching , if want to make a playlist then need this
# Spotify scopes (INCLUDE ugc-image-upload) 
# scope = "user-read-private user-read-playback-state user-modify-playback-state playlist-modify-public playlist-modify-private ugc-image-upload"
# token = util.prompt_for_user_token(spotify_auth.username, scope, client_id=spotify_auth.client_id, client_secret=spotify_auth.client_secret, redirect_uri=spotify_auth.redirectURI)

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
track_results = sp.search(q='I AM', type="track", limit = 5)

# %%
track_results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=I+AM&type=track&offset=0&limit=5',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RHTUrRF63xao58xh9FXYJ'},
#        'href': 'https://api.spotify.com/v1/artists/6RHTUrRF63xao58xh9FXYJ',
#        'id': '6RHTUrRF63xao58xh9FXYJ',
#        'name': 'IVE',
#        'type': 'artist',
#        'uri': 'spotify:artist:6RHTUrRF63xao58xh9FXYJ'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
# ...

# %%
track_results['tracks']['items'][0]['artists'][0]['name']
# Out:
# 'IVE'

# %%
url = track_results['tracks']['items'][0]['album']['images'][0]['url']

# %%
import requests
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt

# URL of the image
image_url = url
response = requests.get(image_url)
img = Image.open(BytesIO(response.content))

# Display the image inline in Jupyter Notebook
plt.imshow(img)
plt.axis('off')  # Hide axes for a cleaner look
plt.show()

# %%
message = 'I want chicken dinner'
message_list = message.split(" ")
message_list
# Out:
# ['I', 'want', 'chicken', 'dinner']

# %%
def search_get_song_name(word):
    track_results = sp.search(q=word, type="track", limit = 20)
    names = [e['name'] for e in track_results['tracks']['items']]
    print(names)
    starts_with = [name for name in names if name.lower().startswith(word.lower())]

    return starts_with

# %%
import random
[message_list]
results_list = search_get_song_name('chicken')
song = random.choice(results_list)
song
# Out:
# ['Chicken', 'Chicken Fried', 'The Chicken Wing Beat', 'Chickenhead (feat. Three 6 Mafia & La Chat)', 'The Chicken in Black', 'Chicken', 'The Chicken Dance', 'Chicken Bop', 'Chicken Soup', 'CHICKEN WING CHICKEN WING SONG - REMIX', 'Chicken Phone', 'Chicken Nugget Song', 'The Chicken Dance', 'CHICKEN TENDIES', 'The Chicken Dance', 'Chicken Noodle Soup', 'Chicken Grease', 'Chicken Noodle Soup (feat. Becky G)', 'The Chicken Wing Beat', 'Chicken Tenders']
# 'Chicken Noodle Soup'

# %%
hidden_message_songs = []
for word in message_list:
    songs_list = search_get_song_name(word)
    print(songs_list)
    song = random.choice(songs_list)
    hidden_message_songs.append(song)

hidden_message_songs
# Out:
# ['IA', "I Love You, I'm Sorry", 'IFHY (feat. Pharrell)', 'I Remember Everything (feat. Kacey Musgraves)', 'I', 'I Had Some Help (Feat. Morgan Wallen)', 'Die With A Smile', 'I Had Some Help (Feat. Morgan Wallen)', 'ガッチュー！ (feat. 初音ミク&鏡音リン&鏡音レン)', 'I Killed You', 'IFHY (feat. Pharrell)', "It's ok I'm ok", 'I2I', "I Smoked Away My Brain (I'm God x Demons Mashup) (feat. Imogen Heap & Clams Casino)", 'i', 'I Wanna Be Yours', 'IDC', 'Ivy', 'IDGAF (feat. Yeat)', 'I Love You So']
# ['IA', "I Love You, I'm Sorry", 'IFHY (feat. Pharrell)', 'I Remember Everything (feat. Kacey Musgraves)', 'I', 'I Had Some Help (Feat. Morgan Wallen)', 'I Had Some Help (Feat. Morgan Wallen)', 'I Killed You', 'IFHY (feat. Pharrell)', "It's ok I'm ok", 'I2I', "I Smoked Away My Brain (I'm God x Demons Mashup) (feat. Imogen Heap & Clams Casino)", 'i', 'I Wanna Be Yours', 'IDC', 'Ivy', 'IDGAF (feat. Yeat)', 'I Love You So']
# ...
